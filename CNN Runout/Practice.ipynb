# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam
import os

# Define image dimensions and batch size
img_width, img_height = 150, 150


# Get the absolute path of the dataset directory
dataset_dir = os.path.abspath('dataset')

# Check if the dataset directory exists
if not os.path.exists(dataset_dir):
    raise FileNotFoundError(f"The dataset directory {dataset_dir} does not exist")

# Create ImageDataGenerator for data augmentation and rescaling
train_datagen = ImageDataGenerator(
    rescale=1.0/255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True,
    validation_split=0.2  # Split data into training and validation sets
)

# Load and preprocess the training data
train_generator = train_datagen.flow_from_directory(
    dataset_dir,
    target_size=(img_width, img_height),
    batch_size=30,
    class_mode='binary',
    subset='training'
)

# Load and preprocess the validation data
validation_generator = train_datagen.flow_from_directory(
    dataset_dir,
    target_size=(img_width, img_height),
    batch_size=30,
    class_mode='binary',
    subset='validation'
)

# Build the CNN model
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(img_width, img_height, 3)),
    MaxPooling2D(pool_size=(2, 2)),
    
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D(pool_size=(2, 2)),
    
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D(pool_size=(2, 2)),
    
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D(pool_size=(2, 2)),
    
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D(pool_size=(2, 2)),
    
    Flatten(),
    
    Dense(512, activation='relu'),
    Dropout(0.5),
    
    Dense(1, activation='sigmoid')
])
# Out:
# Found 153 images belonging to 2 classes.
# Found 37 images belonging to 2 classes.

# %%
# Compile the model
model.compile(optimizer=Adam(learning_rate=0.0001),
              loss='binary_crossentropy',
              metrics=['accuracy'])

# Train the model
history = model.fit(
    train_generator,
    epochs=90,
)


# Evaluate the model on the validation data
loss, accuracy = model.evaluate(validation_generator)
print(f'Validation accuracy: {accuracy * 100:.2f}%')
# Out:
# Epoch 1/90
# 3/3 [==============================] - 14s 5s/step - loss: 0.6917 - accuracy: 0.4967
# Epoch 2/90
# 3/3 [==============================] - 4s 1s/step - loss: 0.6920 - accuracy: 0.4967
# Epoch 3/90
# 3/3 [==============================] - 3s 792ms/step - loss: 0.6950 - accuracy: 0.4902
# Epoch 4/90
# 3/3 [==============================] - 7s 3s/step - loss: 0.6909 - accuracy: 0.5033
# Epoch 5/90
# 3/3 [==============================] - 4s 726ms/step - loss: 0.6917 - accuracy: 0.4902
# Epoch 6/90
# 3/3 [==============================] - 3s 828ms/step - loss: 0.6910 - accuracy: 0.4837
# Epoch 7/90
# 3/3 [==============================] - 4s 2s/step - loss: 0.6881 - accuracy: 0.4967
# Epoch 8/90
# 3/3 [==============================] - 4s 1s/step - loss: 0.6905 - accuracy: 0.4967
# Epoch 9/90
# 3/3 [==============================] - 3s 842ms/step - loss: 0.6884 - accuracy: 0.5033
# Epoch 10/90
# 3/3 [==============================] - 4s 1s/step - loss: 0.6864 - accuracy: 0.4902
# Epoch 11/90
# 3/3 [==============================] - 3s 789ms/step - loss: 0.6875 - accuracy: 0.5033
# Epoch 12/90
# 3/3 [==============================] - 4s 1s/step - loss: 0.6874 - accuracy: 0.4771
# Epoch 13/90
# 3/3 [==============================] - 4s 860ms/step - loss: 0.6860 - accuracy: 0.4902
# Epoch 14/90
# 3/3 [==============================] - 4s 777ms/step - loss: 0.6855 - accuracy: 0.5033
# Epoch 15/90
# 3/3 [==============================] - 4s 770ms/step - loss: 0.6834 - accuracy: 0.5294
# Epoch 16/90
# 3/3 [==============================] - 3s 759ms/step - loss: 0.6792 - accuracy: 0.5098
# Epoch 17/90
# 3/3 [==============================] - 3s 1s/step - loss: 0.6772 - accuracy: 0.5948
# Epoch 18/90
# 3/3 [==============================] - 3s 759ms/step - loss: 0.6735 - accuracy: 0.6536
# Epoch 19/90
# 3/3 [==============================] - 3s 1s/step - loss: 0.6725 - accuracy: 0.5294
# Epoch 20/90
# 3/3 [==============================] - 3s 712ms/step - loss: 0.6682 - accuracy: 0.5359
# Epoch 21/90
# 3/3 [==============================] - 3s 727ms/step - loss: 0.6633 - accuracy: 0.5294
# Epoch 22/90
# 3/3 [==============================] - 3s 712ms/step - loss: 0.6601 - accuracy: 0.6405
# Epoch 23/90
# 3/3 [==============================] - 3s 1s/step - loss: 0.6621 - accuracy: 0.6275
# Epoch 24/90
# 3/3 [==============================] - 3s 1s/step - loss: 0.6509 - accuracy: 0.6667
# Epoch 25/90
# 3/3 [==============================] - 3s 1s/step - loss: 0.6587 - accuracy: 0.6340
# Epoch 26/90
# 3/3 [==============================] - 3s 701ms/step - loss: 0.6368 - accuracy: 0.6144
# Epoch 27/90
# 3/3 [==============================] - 3s 708ms/step - loss: 0.6306 - accuracy: 0.6863
# Epoch 28/90
# 3/3 [==============================] - 3s 722ms/step - loss: 0.6168 - accuracy: 0.6863
# Epoch 29/90
# 3/3 [==============================] - 3s 699ms/step - loss: 0.6274 - accuracy: 0.6601
# Epoch 30/90
# 3/3 [==============================] - 3s 754ms/step - loss: 0.6144 - accuracy: 0.6536
# Epoch 31/90
# 3/3 [==============================] - 3s 714ms/step - loss: 0.5993 - accuracy: 0.6667
# Epoch 32/90
# 3/3 [==============================] - 3s 1s/step - loss: 0.6211 - accuracy: 0.6275
# Epoch 33/90
# 3/3 [==============================] - 3s 741ms/step - loss: 0.5752 - accuracy: 0.7059
# Epoch 34/90
# 3/3 [==============================] - 4s 1s/step - loss: 0.6247 - accuracy: 0.6667
# Epoch 35/90
# 3/3 [==============================] - 4s 923ms/step - loss: 0.6011 - accuracy: 0.6863
# Epoch 36/90
# 3/3 [==============================] - 4s 1s/step - loss: 0.6337 - accuracy: 0.6405
# Epoch 37/90
# 3/3 [==============================] - 4s 2s/step - loss: 0.5772 - accuracy: 0.7059
# Epoch 38/90
# 3/3 [==============================] - 4s 1s/step - loss: 0.6038 - accuracy: 0.6667
# Epoch 39/90
# 3/3 [==============================] - 3s 1s/step - loss: 0.5744 - accuracy: 0.6863
# Epoch 40/90
# 3/3 [==============================] - 4s 1000ms/step - loss: 0.5783 - accuracy: 0.7190
# Epoch 41/90
# 3/3 [==============================] - 3s 805ms/step - loss: 0.5781 - accuracy: 0.6993
# Epoch 42/90
# 3/3 [==============================] - 3s 753ms/step - loss: 0.5705 - accuracy: 0.7059
# Epoch 43/90
# 3/3 [==============================] - 3s 787ms/step - loss: 0.5786 - accuracy: 0.6993
# Epoch 44/90
# 3/3 [==============================] - 3s 831ms/step - loss: 0.5802 - accuracy: 0.6993
# Epoch 45/90
# 3/3 [==============================] - 4s 821ms/step - loss: 0.5772 - accuracy: 0.7059
# Epoch 46/90
# 3/3 [==============================] - 3s 817ms/step - loss: 0.5729 - accuracy: 0.7190
# Epoch 47/90
# 3/3 [==============================] - 3s 789ms/step - loss: 0.5625 - accuracy: 0.7255
# Epoch 48/90
# 3/3 [==============================] - 3s 1s/step - loss: 0.5685 - accuracy: 0.7124
# Epoch 49/90
# 3/3 [==============================] - 4s 1s/step - loss: 0.5634 - accuracy: 0.7059
# Epoch 50/90
# 3/3 [==============================] - 3s 1s/step - loss: 0.5646 - accuracy: 0.7386
# Epoch 51/90
# 3/3 [==============================] - 4s 950ms/step - loss: 0.5607 - accuracy: 0.7124
# Epoch 52/90
# 3/3 [==============================] - 3s 796ms/step - loss: 0.5449 - accuracy: 0.7582
# Epoch 53/90
# 3/3 [==============================] - 3s 824ms/step - loss: 0.5509 - accuracy: 0.7059
# Epoch 54/90
# 3/3 [==============================] - 4s 824ms/step - loss: 0.5570 - accuracy: 0.6928
# Epoch 55/90
# 3/3 [==============================] - 3s 771ms/step - loss: 0.5597 - accuracy: 0.7124
# Epoch 56/90
# 3/3 [==============================] - 3s 800ms/step - loss: 0.5387 - accuracy: 0.7255
# Epoch 57/90
# 3/3 [==============================] - 3s 1s/step - loss: 0.5397 - accuracy: 0.6928
# Epoch 58/90
# 3/3 [==============================] - 3s 762ms/step - loss: 0.5412 - accuracy: 0.7255
# Epoch 59/90
# 3/3 [==============================] - 4s 2s/step - loss: 0.5641 - accuracy: 0.7059
# Epoch 60/90
# 3/3 [==============================] - 4s 1s/step - loss: 0.5694 - accuracy: 0.6732
# Epoch 61/90
# 3/3 [==============================] - 3s 752ms/step - loss: 0.5326 - accuracy: 0.7255
# Epoch 62/90
# 3/3 [==============================] - 3s 1s/step - loss: 0.6205 - accuracy: 0.6601
# Epoch 63/90
# 3/3 [==============================] - 3s 1s/step - loss: 0.5516 - accuracy: 0.7059
# Epoch 64/90
# 3/3 [==============================] - 3s 1s/step - loss: 0.5643 - accuracy: 0.6732
# Epoch 65/90
# 3/3 [==============================] - 3s 699ms/step - loss: 0.5436 - accuracy: 0.7190
# Epoch 66/90
# 3/3 [==============================] - 3s 1s/step - loss: 0.6141 - accuracy: 0.6536
# Epoch 67/90
# 3/3 [==============================] - 3s 1s/step - loss: 0.5763 - accuracy: 0.6928
# Epoch 68/90
# 3/3 [==============================] - 3s 1s/step - loss: 0.5599 - accuracy: 0.7124
# Epoch 69/90
# 3/3 [==============================] - 3s 1s/step - loss: 0.5621 - accuracy: 0.6863
# Epoch 70/90
# 3/3 [==============================] - 3s 725ms/step - loss: 0.5481 - accuracy: 0.7451
# Epoch 71/90
# 3/3 [==============================] - 3s 688ms/step - loss: 0.5532 - accuracy: 0.6993
# Epoch 72/90
# 3/3 [==============================] - 3s 688ms/step - loss: 0.5368 - accuracy: 0.7255
# Epoch 73/90
# 3/3 [==============================] - 3s 661ms/step - loss: 0.5613 - accuracy: 0.6797
# Epoch 74/90
# 3/3 [==============================] - 3s 1s/step - loss: 0.5404 - accuracy: 0.6993
# Epoch 75/90
# 3/3 [==============================] - 3s 668ms/step - loss: 0.5416 - accuracy: 0.7059
# Epoch 76/90
# 3/3 [==============================] - 3s 681ms/step - loss: 0.5500 - accuracy: 0.7320
# Epoch 77/90
# 3/3 [==============================] - 3s 742ms/step - loss: 0.5204 - accuracy: 0.7320
# Epoch 78/90
# 3/3 [==============================] - 3s 1s/step - loss: 0.5270 - accuracy: 0.7647
# Epoch 79/90
# 3/3 [==============================] - 3s 1s/step - loss: 0.5143 - accuracy: 0.7712
# Epoch 80/90
# 3/3 [==============================] - 3s 750ms/step - loss: 0.5242 - accuracy: 0.7516
# Epoch 81/90
# 3/3 [==============================] - 3s 685ms/step - loss: 0.5176 - accuracy: 0.7712
# Epoch 82/90
# 3/3 [==============================] - 3s 747ms/step - loss: 0.4970 - accuracy: 0.7712
# Epoch 83/90
# 3/3 [==============================] - 3s 722ms/step - loss: 0.5110 - accuracy: 0.7386
# Epoch 84/90
# 3/3 [==============================] - 3s 706ms/step - loss: 0.4984 - accuracy: 0.7712
# Epoch 85/90
# 3/3 [==============================] - 3s 707ms/step - loss: 0.5116 - accuracy: 0.7451
# Epoch 86/90
# 3/3 [==============================] - 3s 663ms/step - loss: 0.5006 - accuracy: 0.7712
# Epoch 87/90
# 3/3 [==============================] - 3s 1s/step - loss: 0.4990 - accuracy: 0.7582
# Epoch 88/90
# 3/3 [==============================] - 3s 1s/step - loss: 0.4833 - accuracy: 0.7974
# Epoch 89/90
# 3/3 [==============================] - 3s 1s/step - loss: 0.5081 - accuracy: 0.7190
# Epoch 90/90
# 3/3 [==============================] - 4s 795ms/step - loss: 0.5029 - accuracy: 0.7451
# 1/1 [==============================] - 1s 1s/step - loss: 0.7690 - accuracy: 0.6486
# Validation accuracy: 64.86%

# %%
model.save('out_notout_classifier.h5')

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing import image
import numpy as np
import os

def predict_image(img_path):
    img_width, img_height = 150, 150

    # Load and preprocess the image
    img = image.load_img(img_path, target_size=(img_width, img_height))
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)  # Add batch dimension
    img_array /= 255.0  # Rescale the image

    # Make prediction
    prediction = model.predict(img_array)
    
    # Output the result
    if prediction[0] > 0.5:
        print('The image is classified as: Not Out')
    else:
        print('The image is classified as: Out')

# Example usage
image_path = 'a1.jpg'
predict_image(image_path)
# Out:
# 1/1 [==============================] - 0s 55ms/step
# The image is classified as: Out

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.optimizers import Adam
import os

# Define image dimensions and batch size
img_width, img_height = 150, 150
batch_size = 32
num_epochs = 90  # Set the number of epochs

# Get the absolute path of the dataset directory
dataset_dir = os.path.abspath('dataset')

# Check if the dataset directory exists
if not os.path.exists(dataset_dir):
    raise FileNotFoundError(f"The dataset directory {dataset_dir} does not exist")

# Create ImageDataGenerator for data augmentation and rescaling
train_datagen = ImageDataGenerator(
    rescale=1.0/255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True
)

# Load and preprocess the training data
train_generator = train_datagen.flow_from_directory(
    dataset_dir,
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='binary'
)

# Build the CNN model
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(img_width, img_height, 3)),
    MaxPooling2D(pool_size=(2, 2)),
    
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D(pool_size=(2, 2)),
    
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D(pool_size=(2, 2)),
    
    Conv2D(128, (3, 3), activation='relu'),
    MaxPooling2D(pool_size=(2, 2)),
    
    Flatten(),
    
    Dense(512, activation='relu'),
    Dropout(0.5),
    
    Dense(1, activation='sigmoid')
])

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.0001),
              loss='binary_crossentropy',
              metrics=['accuracy'])

# Train the model
history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // batch_size,
    epochs=num_epochs
)

# Save the model
model.save('out_notout_classifier.h5')
# Out:
# Found 190 images belonging to 2 classes.
# Epoch 1/90
# 5/5 [==============================] - 6s 782ms/step - loss: 0.7069 - accuracy: 0.4812
# Epoch 2/90
# 5/5 [==============================] - 5s 907ms/step - loss: 0.7043 - accuracy: 0.4875
# Epoch 3/90
# 5/5 [==============================] - 5s 906ms/step - loss: 0.6901 - accuracy: 0.5506
# Epoch 4/90
# 5/5 [==============================] - 5s 957ms/step - loss: 0.7027 - accuracy: 0.4937
# Epoch 5/90
# 5/5 [==============================] - 4s 750ms/step - loss: 0.6780 - accuracy: 0.6203
# Epoch 6/90
# 5/5 [==============================] - 4s 772ms/step - loss: 0.6693 - accuracy: 0.5253
# Epoch 7/90
# 5/5 [==============================] - 4s 778ms/step - loss: 0.6590 - accuracy: 0.5949
# Epoch 8/90
# 5/5 [==============================] - 4s 761ms/step - loss: 0.6532 - accuracy: 0.6329
# Epoch 9/90
# 5/5 [==============================] - 4s 763ms/step - loss: 0.6464 - accuracy: 0.6835
# Epoch 10/90
# 5/5 [==============================] - 4s 749ms/step - loss: 0.6409 - accuracy: 0.6266
# Epoch 11/90
# 5/5 [==============================] - 4s 778ms/step - loss: 0.6032 - accuracy: 0.6835
# Epoch 12/90
# 5/5 [==============================] - 4s 747ms/step - loss: 0.6033 - accuracy: 0.7025
# Epoch 13/90
# 5/5 [==============================] - 4s 773ms/step - loss: 0.5593 - accuracy: 0.6835
# Epoch 14/90
# 5/5 [==============================] - 4s 750ms/step - loss: 0.6105 - accuracy: 0.6772
# Epoch 15/90
# 5/5 [==============================] - 4s 783ms/step - loss: 0.5746 - accuracy: 0.7215
# Epoch 16/90
# 5/5 [==============================] - 4s 762ms/step - loss: 0.5852 - accuracy: 0.6835
# Epoch 17/90
# 5/5 [==============================] - 4s 771ms/step - loss: 0.5702 - accuracy: 0.7063
# Epoch 18/90
# 5/5 [==============================] - 4s 749ms/step - loss: 0.5801 - accuracy: 0.6899
# Epoch 19/90
# 5/5 [==============================] - 4s 775ms/step - loss: 0.5866 - accuracy: 0.7375
# Epoch 20/90
# 5/5 [==============================] - 5s 852ms/step - loss: 0.5537 - accuracy: 0.7152
# Epoch 21/90
# 5/5 [==============================] - 5s 925ms/step - loss: 0.5153 - accuracy: 0.7785
# Epoch 22/90
# 5/5 [==============================] - 4s 815ms/step - loss: 0.5075 - accuracy: 0.7468
# 5/5 [==============================] - 4s 700ms/step - loss: 0.3048 - accuracy: 0.8861
# Epoch 81/90
# 5/5 [==============================] - 4s 756ms/step - loss: 0.2860 - accuracy: 0.8797
# Epoch 82/90
# 5/5 [==============================] - 4s 713ms/step - loss: 0.2563 - accuracy: 0.9241
# Epoch 83/90
# 5/5 [==============================] - 4s 708ms/step - loss: 0.2786 - accuracy: 0.9000
# Epoch 84/90
# 5/5 [==============================] - 4s 756ms/step - loss: 0.3055 - accuracy: 0.8687
# Epoch 85/90
# 5/5 [==============================] - 4s 699ms/step - loss: 0.2976 - accuracy: 0.8924
# Epoch 86/90
# 5/5 [==============================] - 4s 698ms/step - loss: 0.2936 - accuracy: 0.9051
# Epoch 87/90
# 5/5 [==============================] - 4s 717ms/step - loss: 0.2987 - accuracy: 0.8608
# Epoch 88/90
# 5/5 [==============================] - 4s 725ms/step - loss: 0.2883 - accuracy: 0.8924
# Epoch 89/90
# 5/5 [==============================] - 4s 708ms/step - loss: 0.2407 - accuracy: 0.8924
# Epoch 90/90
# 5/5 [==============================] - 4s 709ms/step - loss: 0.2543 - accuracy: 0.9304
# c:\Users\Dell\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
from tensorflow.keras.preprocessing import image
import numpy as np

def predict_image(img_path):
    img_width, img_height = 150, 150

    # Load and preprocess the image
    img = image.load_img(img_path, target_size=(img_width, img_height))
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)  # Add batch dimension
    img_array /= 255.0  # Rescale the image

    # Make prediction
    prediction = model.predict(img_array)
    
    # Output the result
    if prediction[0] > 0.5:
        print('The image is classified as: Not Out')
    else:
        print('The image is classified as: Out')

# Example usage
image_path = 'a2.jpg'
predict_image(image_path)
# Out:
# 1/1 [==============================] - 0s 53ms/step
# The image is classified as: Out

# %%
import tensorflow as tf

# Load the saved model
model = tf.keras.models.load_model('out_notout_classifier.h5')
# Recreate the ImageDataGenerator for the training data
train_datagen = ImageDataGenerator(
    rescale=1.0/255,
    shear_range=0.2,
    zoom_range=0.2,
    horizontal_flip=True
)

# Load and preprocess the training data
train_generator = train_datagen.flow_from_directory(
    'dataset',
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='binary'
)

# Evaluate the model on the training data
train_loss, train_accuracy = model.evaluate(train_generator)
print(f'Training accuracy: {train_accuracy * 100:.2f}%')
# Out:
# Found 190 images belonging to 2 classes.
# WARNING:tensorflow:5 out of the last 12 calls to <function Model.make_test_function.<locals>.test_function at 0x00000284CC83AB00> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 6/6 [==============================] - 3s 416ms/step - loss: 0.2055 - accuracy: 0.9526
# Training accuracy: 95.26%

# %%
from tensorflow.keras.preprocessing import image
import numpy as np

def predict_image(model, img_path):
    img_width, img_height = 150, 150

    # Load and preprocess the image
    img = image.load_img(img_path, target_size=(img_width, img_height))
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)  # Add batch dimension
    img_array /= 255.0  # Rescale the image

    # Make prediction
    prediction = model.predict(img_array)
    print(f'Raw prediction value: {prediction[0]}')

    # Output the result
    if prediction[0] > 0.5:
        print('The image is classified as: Not Out')
    else:
        print('The image is classified as: Out')

# Example usage
image_path = 'a2.jpg'
predict_image(model, image_path)
# Out:
# 1/1 [==============================] - 0s 185ms/step
# Raw prediction value: [0.00175371]
# The image is classified as: Out

# %%
# Recreate the ImageDataGenerator for the training data
train_datagen = ImageDataGenerator(rescale=1.0/255)

# Load and preprocess the training data
train_generator = train_datagen.flow_from_directory(
    'dataset',
    target_size=(img_width, img_height),
    batch_size=batch_size,
    class_mode='binary',
    shuffle=False  # Ensure images are loaded in the same order
)

# Evaluate the model on the training data
train_loss, train_accuracy = model.evaluate(train_generator, steps=len(train_generator))
print(f'Training accuracy (evaluation): {train_accuracy * 100:.2f}%')
# Out:
# Found 190 images belonging to 2 classes.
# 6/6 [==============================] - 2s 246ms/step - loss: 0.3224 - accuracy: 0.8632
# Training accuracy (evaluation): 86.32%

# %%
import numpy as np

# Get filenames and true labels
filenames = train_generator.filenames
true_labels = train_generator.classes

# Predict on the training data
predictions = model.predict(train_generator, steps=len(train_generator), verbose=1)
predicted_labels = np.where(predictions > 0.5, 1, 0).flatten()

# Compare true and predicted labels
for i in range(len(filenames)):
    print(f"Filename: {filenames[i]}")
    print(f"True label: {'Not Out' if true_labels[i] == 1 else 'Out'}")
    print(f"Predicted label: {'Not Out' if predicted_labels[i] == 1 else 'Out'}\n")
# Out:
# WARNING:tensorflow:5 out of the last 13 calls to <function Model.make_predict_function.<locals>.predict_function at 0x00000284A48057E0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 6/6 [==============================] - 2s 214ms/step
# Filename: not_out\Screenshot 2024-06-17 142747.jpg
# True label: Out
# Predicted label: Out
#
# Filename: not_out\Screenshot 2024-06-17 142949.jpg
# True label: Out
# Predicted label: Out
#
# Filename: not_out\Screenshot 2024-06-17 143540.jpg
# True label: Out
# Predicted label: Out
#
# Filename: not_out\Screenshot 2024-06-17 144005.jpg
# True label: Out
# Predicted label: Out
#
# Filename: not_out\Screenshot 2024-06-17 144056.jpg
# True label: Out
# Predicted label: Out
#
# Filename: not_out\Screenshot 2024-06-17 144646.jpg
# True label: Out
# Predicted label: Out
#
# Filename: not_out\Screenshot 2024-06-17 144712.jpg
# True label: Out
# Predicted label: Out
#
# Filename: not_out\Screenshot 2024-06-17 144843.jpg
# True label: Out
# Predicted label: Out
#
# Filename: not_out\Screenshot 2024-06-17 145057.jpg
# True label: Out
# Predicted label: Out
#
# Filename: not_out\Screenshot 2024-06-17 145243.jpg
# True label: Out
# Predicted label: Out
#
# Filename: not_out\Screenshot 2024-06-17 145327.jpg
# True label: Out
# Predicted label: Out
#
# Filename: not_out\Screenshot 2024-06-17 145442.jpg
# True label: Out
# Predicted label: Out
#
# Filename: not_out\Screenshot 2024-06-17 145559.jpg
# True label: Out
# Predicted label: Not Out
#
# Filename: not_out\Screenshot 2024-06-17 145727.jpg
# True label: Out
# Predicted label: Out
#
# Filename: not_out\Screenshot 2024-06-17 145806.jpg
# True label: Out
# Predicted label: Out
#
# Filename: not_out\Screenshot 2024-06-17 150134.jpg
# True label: Out
# Predicted label: Out
#
# Filename: not_out\Screenshot 2024-06-17 150650.jpg
# True label: Out
# Predicted label: Out
#
# Filename: not_out\Screenshot 2024-06-17 150800.jpg
# True label: Out
# Predicted label: Out
#
# Filename: not_out\Screenshot 2024-06-17 150958.jpg
# True label: Out
# Predicted label: Out
#
# Filename: not_out\Screenshot 2024-06-17 151234.jpg
# True label: Out
# Predicted label: Out
#
# Filename: not_out\ghhgdfd (1).jpg
# True label: Out
# Predicted label: Out
#
# Filename: not_out\ghhgdfd (11).jpg
# True label: Out
# Predicted label: Not Out
#
# Filename: not_out\ghhgdfd (13).jpg
# True label: Out
# Predicted label: Out
#
# Filename: not_out\ghhgdfd (14).jpg
# True label: Out
# Predicted label: Out
#
# Filename: not_out\ghhgdfd (15).jpg
# True label: Out
# Predicted label: Out
#
# Filename: not_out\ghhgdfd (17).jpg
# True label: Out
# Predicted label: Out
#
# Filename: not_out\ghhgdfd (2).jpg
# True label: Out
# Predicted label: Out
#
# Filename: not_out\ghhgdfd (20).jpg
# True label: Out
# Predicted label: Out
#
# Filename: not_out\ghhgdfd (21).jpg
# True label: Out
# Predicted label: Out
#
# Filename: not_out\ghhgdfd (22).jpg
# True label: Out
# Predicted label: Out
#
# Filename: not_out\ghhgdfd (23).jpg
# True label: Out
# Predicted label: Out
#
# Filename: not_out\ghhgdfd (24).jpg
# True label: Out
# Predicted label: Out
#
# Filename: not_out\ghhgdfd (25).jpg
# True label: Out
# Predicted label: Out
#
# Filename: not_out\ghhgdfd (26).jpg
# True label: Out
# Predicted label: Out
#
# Filename: not_out\ghhgdfd (27).jpg
# True label: Out
# Predicted label: Out
#
# Filename: not_out\ghhgdfd (28).jpg
# True label: Out
# Predicted label: Out
#
# Filename: not_out\ghhgdfd (3).jpg
# True label: Out
# Predicted label: Out
#
# Filename: not_out\ghhgdfd (30).jpg
# True label: Out
# Predicted label: Out
#
# Filename: not_out\ghhgdfd (31).jpg
# True label: Out
# Predicted label: Out
#
# Filename: not_out\ghhgdfd (33).jpg
# True label: Out
# Predicted label: Out
#
# Filename: not_out\ghhgdfd (34).jpg
# True label: Out
# Predicted label: Out
#
# Filename: not_out\ghhgdfd (35).jpg
# True label: Out
# Predicted label: Out
#
# Filename: not_out\ghhgdfd (36).jpg
# True label: Out
# Predicted label: Out
#
# Filename: not_out\ghhgdfd (37).jpg
# True label: Out
# Predicted label: Out
#
# Filename: not_out\ghhgdfd (38).jpg
# True label: Out
# Predicted label: Out
#
# Filename: not_out\ghhgdfd (39).jpg
# True label: Out
# Predicted label: Out
#
# Filename: not_out\ghhgdfd (40).jpg
# True label: Out
# Predicted label: Out
#
# Filename: not_out\ghhgdfd (41).jpg
# True label: Out
# Predicted label: Out
#
# Filename: not_out\ghhgdfd (42).jpg
# True label: Out
# Predicted label: Out
#
# Filename: not_out\ghhgdfd (43).jpg
# True label: Out
# Predicted label: Out
#
# Filename: not_out\ghhgdfd (44).jpg
# True label: Out
# Predicted label: Out
#
# Filename: not_out\ghhgdfd (45).jpg
# True label: Out
# Predicted label: Out
#
# Filename: not_out\ghhgdfd (46).jpg
# True label: Out
# Predicted label: Out
#
# Filename: not_out\ghhgdfd (47).jpg
# True label: Out
# Predicted label: Out
#
# Filename: not_out\ghhgdfd (48).jpg
# True label: Out
# Predicted label: Out
#
# Filename: not_out\ghhgdfd (49).jpg
# True label: Out
# Predicted label: Out
#
# Filename: not_out\ghhgdfd (5).jpg
# True label: Out
# Predicted label: Out
#
# Filename: not_out\ghhgdfd (50).jpg
# True label: Out
# Predicted label: Out
#
# Filename: not_out\ghhgdfd (51).jpg
# True label: Out
# Predicted label: Out
#
# Filename: not_out\ghhgdfd (52).jpg
# True label: Out
# Predicted label: Out
#
# Filename: not_out\ghhgdfd (53).jpg
# True label: Out
# Predicted label: Out
#
# Filename: not_out\ghhgdfd (54).jpg
# True label: Out
# Predicted label: Out
#
# Filename: not_out\ghhgdfd (55).jpg
# True label: Out
# Predicted label: Out
#
# Filename: not_out\ghhgdfd (56).jpg
# True label: Out
# Predicted label: Out
#
# Filename: not_out\ghhgdfd (57).jpg
# True label: Out
# Predicted label: Out
#
# Filename: not_out\ghhgdfd (58).jpg
# True label: Out
# Predicted label: Out
#
# Filename: not_out\ghhgdfd (59).jpg
# True label: Out
# Predicted label: Out
#
# Filename: not_out\ghhgdfd (6).jpg
# True label: Out
# Predicted label: Out
#
# Filename: not_out\ghhgdfd (60).jpg
# True label: Out
# Predicted label: Out
#
# Filename: not_out\ghhgdfd (61).jpg
# True label: Out
# Predicted label: Out
#
# Filename: not_out\ghhgdfd (62).jpg
# True label: Out
# Predicted label: Out
#
# Filename: not_out\ghhgdfd (63).jpg
# True label: Out
# Predicted label: Out
#
# Filename: not_out\ghhgdfd (64).jpg
# True label: Out
# Predicted label: Out
#
# Filename: not_out\ghhgdfd (65).jpg
# True label: Out
# Predicted label: Out
#
# Filename: not_out\ghhgdfd (66).jpg
# True label: Out
# Predicted label: Out
#
# Filename: not_out\ghhgdfd (67).jpg
# True label: Out
# Predicted label: Out
#
# Filename: not_out\ghhgdfd (68).jpg
# True label: Out
# Predicted label: Out
#
# Filename: not_out\ghhgdfd (69).jpg
# True label: Out
# Predicted label: Out
#
# Filename: not_out\ghhgdfd (7).jpg
# True label: Out
# Predicted label: Out
#
# Filename: not_out\ghhgdfd (70).jpg
# True label: Out
# Predicted label: Out
#
# Filename: not_out\ghhgdfd (71).jpg
# True label: Out
# Predicted label: Out
#
# Filename: not_out\ghhgdfd (72).jpg
# True label: Out
# Predicted label: Out
#
# Filename: not_out\ghhgdfd (73).jpg
# True label: Out
# Predicted label: Out
#
# Filename: not_out\ghhgdfd (74).jpg
# True label: Out
# Predicted label: Out
#
# Filename: not_out\ghhgdfd (75).jpg
# True label: Out
# Predicted label: Out
#
# Filename: not_out\ghhgdfd (76).jpg
# True label: Out
# Predicted label: Out
#
# Filename: not_out\ghhgdfd (77).jpg
# True label: Out
# Predicted label: Out
#
# Filename: not_out\ghhgdfd (78).jpg
# True label: Out
# Predicted label: Out
#
# Filename: not_out\ghhgdfd (79).jpg
# True label: Out
# Predicted label: Out
#
# Filename: not_out\ghhgdfd (8).jpg
# True label: Out
# Predicted label: Out
#
# Filename: not_out\ghhgdfd (80).jpg
# True label: Out
# Predicted label: Out
#
# Filename: not_out\ghhgdfd (81).jpg
# True label: Out
# Predicted label: Out
#
# Filename: not_out\ghhgdfd (82).jpg
# True label: Out
# Predicted label: Out
#
# Filename: out\2.jpg
# True label: Not Out
# Predicted label: Out
#
# Filename: out\3.jpg
# True label: Not Out
# Predicted label: Not Out
#
# Filename: out\4.jpg
# True label: Not Out
# Predicted label: Out
#
# Filename: out\Screenshot 2024-06-16 110022.jpg
# True label: Not Out
# Predicted label: Not Out
#
# Filename: out\Screenshot 2024-06-16 110120.jpg
# True label: Not Out
# Predicted label: Not Out
#
# Filename: out\Screenshot 2024-06-16 110229.jpg
# True label: Not Out
# Predicted label: Not Out
#
# Filename: out\Screenshot 2024-06-16 110310.jpg
# True label: Not Out
# Predicted label: Out
#
# Filename: out\Screenshot 2024-06-16 110408.jpg
# True label: Not Out
# Predicted label: Not Out
#
# Filename: out\Screenshot 2024-06-16 110441.jpg
# True label: Not Out
# Predicted label: Not Out
#
# Filename: out\Screenshot 2024-06-16 110516.jpg
# True label: Not Out
# Predicted label: Not Out
#
# Filename: out\Screenshot 2024-06-16 110612.jpg
# True label: Not Out
# Predicted label: Not Out
#
# Filename: out\Screenshot 2024-06-16 110645.jpg
# True label: Not Out
# Predicted label: Not Out
#
# Filename: out\Screenshot 2024-06-16 110727.jpg
# True label: Not Out
# Predicted label: Not Out
#
# Filename: out\Screenshot 2024-06-16 110755.jpg
# True label: Not Out
# Predicted label: Not Out
#
# Filename: out\Screenshot 2024-06-16 110936.jpg
# True label: Not Out
# Predicted label: Not Out
#
# Filename: out\Screenshot 2024-06-16 110957.jpg
# True label: Not Out
# Predicted label: Not Out
#
# Filename: out\Screenshot 2024-06-16 111123.jpg
# True label: Not Out
# Predicted label: Not Out
#
# Filename: out\Screenshot 2024-06-16 111326.jpg
# True label: Not Out
# Predicted label: Out
#
# Filename: out\Screenshot 2024-06-16 111419.jpg
# True label: Not Out
# Predicted label: Not Out
#
# Filename: out\Screenshot 2024-06-16 111658.jpg
# True label: Not Out
# Predicted label: Not Out
#
# Filename: out\Screenshot 2024-06-16 111811.jpg
# True label: Not Out
# Predicted label: Not Out
#
# Filename: out\Screenshot 2024-06-16 111857.jpg
# True label: Not Out
# Predicted label: Not Out
#
# Filename: out\Screenshot 2024-06-16 112034.jpg
# True label: Not Out
# Predicted label: Out
#
# Filename: out\Screenshot 2024-06-16 112325.jpg
# True label: Not Out
# Predicted label: Out
#
# Filename: out\Screenshot 2024-06-16 112403.jpg
# True label: Not Out
# Predicted label: Out
#
# Filename: out\Screenshot 2024-06-16 112453.jpg
# True label: Not Out
# Predicted label: Not Out
#
# Filename: out\Screenshot 2024-06-16 112601.jpg
# True label: Not Out
# Predicted label: Not Out
#
# Filename: out\Screenshot 2024-06-16 112643.jpg
# True label: Not Out
# Predicted label: Out
#
# Filename: out\Screenshot 2024-06-16 112719.jpg
# True label: Not Out
# Predicted label: Not Out
#
# Filename: out\Screenshot 2024-06-16 112751.jpg
# True label: Not Out
# Predicted label: Not Out
#
# Filename: out\Screenshot 2024-06-16 112823.jpg
# True label: Not Out
# Predicted label: Out
#
# Filename: out\Screenshot 2024-06-16 112909.jpg
# True label: Not Out
# Predicted label: Not Out
#
# Filename: out\Screenshot 2024-06-16 112941.jpg
# True label: Not Out
# Predicted label: Out
#
# Filename: out\Screenshot 2024-06-16 113018.jpg
# True label: Not Out
# Predicted label: Out
#
# Filename: out\Screenshot 2024-06-16 113100.jpg
# True label: Not Out
# Predicted label: Out
#
# Filename: out\Screenshot 2024-06-16 113133.jpg
# True label: Not Out
# Predicted label: Not Out
#
# Filename: out\Screenshot 2024-06-16 113228.jpg
# True label: Not Out
# Predicted label: Not Out
#
# Filename: out\Screenshot 2024-06-16 113308.jpg
# True label: Not Out
# Predicted label: Not Out
#
# Filename: out\Screenshot 2024-06-16 113455.jpg
# True label: Not Out
# Predicted label: Not Out
#
# Filename: out\Screenshot 2024-06-16 113526.jpg
# True label: Not Out
# Predicted label: Not Out
#
# Filename: out\Screenshot 2024-06-16 113637.jpg
# True label: Not Out
# Predicted label: Not Out
#
# Filename: out\Screenshot 2024-06-16 113712.jpg
# True label: Not Out
# Predicted label: Not Out
#
# Filename: out\Screenshot 2024-06-16 113747.jpg
# True label: Not Out
# Predicted label: Not Out
#
# Filename: out\Screenshot 2024-06-16 113823.jpg
# True label: Not Out
# Predicted label: Not Out
#
# Filename: out\Screenshot 2024-06-16 113904.jpg
# True label: Not Out
# Predicted label: Not Out
#
# Filename: out\Screenshot 2024-06-16 113951.jpg
# True label: Not Out
# Predicted label: Not Out
#
# Filename: out\Screenshot 2024-06-16 114355.jpg
# True label: Not Out
# Predicted label: Not Out
#
# Filename: out\Screenshot 2024-06-16 114908.jpg
# True label: Not Out
# Predicted label: Not Out
#
# Filename: out\Screenshot 2024-06-16 115232.jpg
# True label: Not Out
# Predicted label: Not Out
#
# Filename: out\Screenshot 2024-06-16 115315.jpg
# True label: Not Out
# Predicted label: Not Out
#
# Filename: out\Screenshot 2024-06-16 115412.jpg
# True label: Not Out
# Predicted label: Not Out
#
# Filename: out\Screenshot 2024-06-16 115505.jpg
# True label: Not Out
# Predicted label: Not Out
#
# Filename: out\Screenshot 2024-06-16 115553.jpg
# True label: Not Out
# Predicted label: Out
#
# Filename: out\Screenshot 2024-06-16 115739.jpg
# True label: Not Out
# Predicted label: Not Out
#
# Filename: out\Screenshot 2024-06-16 115824.jpg
# True label: Not Out
# Predicted label: Out
#
# Filename: out\Screenshot 2024-06-16 115932.jpg
# True label: Not Out
# Predicted label: Out
#
# Filename: out\Screenshot 2024-06-16 120145.jpg
# True label: Not Out
# Predicted label: Not Out
#
# Filename: out\Screenshot 2024-06-16 120246.jpg
# True label: Not Out
# Predicted label: Not Out
#
# Filename: out\Screenshot 2024-06-16 120348.jpg
# True label: Not Out
# Predicted label: Out
#
# Filename: out\Screenshot 2024-06-16 120436.jpg
# True label: Not Out
# Predicted label: Out
#
# Filename: out\Screenshot 2024-06-16 120529.jpg
# True label: Not Out
# Predicted label: Not Out
#
# Filename: out\Screenshot 2024-06-16 120556.jpg
# True label: Not Out
# Predicted label: Out
#
# Filename: out\Screenshot 2024-06-16 120644.jpg
# True label: Not Out
# Predicted label: Not Out
#
# Filename: out\Screenshot 2024-06-16 120731.jpg
# True label: Not Out
# Predicted label: Not Out
#
# Filename: out\Screenshot 2024-06-16 120909.jpg
# True label: Not Out
# Predicted label: Not Out
#
# Filename: out\Screenshot 2024-06-16 120930.jpg
# True label: Not Out
# Predicted label: Not Out
#
# Filename: out\Screenshot 2024-06-16 121050.jpg
# True label: Not Out
# Predicted label: Not Out
#
# Filename: out\Screenshot 2024-06-16 121118.jpg
# True label: Not Out
# Predicted label: Out
#
# Filename: out\Screenshot 2024-06-16 121149.jpg
# True label: Not Out
# Predicted label: Not Out
#
# Filename: out\Screenshot 2024-06-16 121932.jpg
# True label: Not Out
# Predicted label: Not Out
#
# Filename: out\Screenshot 2024-06-16 121951.jpg
# True label: Not Out
# Predicted label: Not Out
#
# Filename: out\Screenshot 2024-06-16 122114.jpg
# True label: Not Out
# Predicted label: Not Out
#
# Filename: out\Screenshot 2024-06-16 122154.jpg
# True label: Not Out
# Predicted label: Not Out
#
# Filename: out\Screenshot 2024-06-16 122235.jpg
# True label: Not Out
# Predicted label: Not Out
#
# Filename: out\Screenshot 2024-06-16 122257.jpg
# True label: Not Out
# Predicted label: Not Out
#
# Filename: out\Screenshot 2024-06-16 122333.jpg
# True label: Not Out
# Predicted label: Not Out
#
# Filename: out\Screenshot 2024-06-16 122414.jpg
# True label: Not Out
# Predicted label: Not Out
#
# Filename: out\Screenshot 2024-06-16 123255.jpg
# True label: Not Out
# Predicted label: Not Out
#
# Filename: out\Screenshot 2024-06-16 123344.jpg
# True label: Not Out
# Predicted label: Out
#
# Filename: out\Screenshot 2024-06-16 123716.jpg
# True label: Not Out
# Predicted label: Not Out
#
# Filename: out\Screenshot 2024-06-16 123839.jpg
# True label: Not Out
# Predicted label: Out
#
# Filename: out\Screenshot 2024-06-16 123954.jpg
# True label: Not Out
# Predicted label: Not Out
#
# Filename: out\Screenshot 2024-06-16 124146.jpg
# True label: Not Out
# Predicted label: Not Out
#
# Filename: out\Screenshot 2024-06-16 124308.jpg
# True label: Not Out
# Predicted label: Not Out
#
# Filename: out\Screenshot 2024-06-16 124349.jpg
# True label: Not Out
# Predicted label: Not Out
#
# Filename: out\Screenshot 2024-06-16 124426.jpg
# True label: Not Out
# Predicted label: Not Out
#
# Filename: out\Screenshot 2024-06-16 124526.jpg
# True label: Not Out
# Predicted label: Out
#
# Filename: out\Screenshot 2024-06-16 124548.jpg
# True label: Not Out
# Predicted label: Not Out
#
# Filename: out\Screenshot 2024-06-16 125009.jpg
# True label: Not Out
# Predicted label: Out
#
# Filename: out\Screenshot 2024-06-16 125152.jpg
# True label: Not Out
# Predicted label: Not Out
#
# Filename: out\Screenshot 2024-06-16 125228.jpg
# True label: Not Out
# Predicted label: Not Out
#
# Filename: out\Screenshot 2024-06-16 125334.jpg
# True label: Not Out
# Predicted label: Not Out
#
# Filename: out\Screenshot 2024-06-16 125428.jpg
# True label: Not Out
# Predicted label: Not Out
#
# Filename: out\download.jpg
# True label: Not Out
# Predicted label: Not Out
#
# Filename: out\images.jpg
# True label: Not Out
# Predicted label: Not Out
#
# Filename: out\maxresdefault.jpg
# True label: Not Out
# Predicted label: Not Out
#
# Filename: out\odsfsf.jpg
# True label: Not Out
# Predicted label: Out
